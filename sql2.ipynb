# %%
import pandas as pd
import sqlite3

# %%
cnx = sqlite3.connect('cindo.db')

# %%
sql_df = pd.read_sql_query("SELECT * from sqlite_master;",cnx)

# %%
sql_df
# Out:
#      type                               name         tbl_name  rootpage  \
# 0   table                             albums           albums         2
# 1   table                    sqlite_sequence  sqlite_sequence         3
# 2   table                            artists          artists         4
# 3   table                          customers        customers         5
# 4   table                          employees        employees         8
# 5   table                             genres           genres        10
# 6   table                           invoices         invoices        11
# 7   table                      invoice_items    invoice_items        13
# 8   table                        media_types      media_types        15
# 9   table                          playlists        playlists        16
# 10  table                     playlist_track   playlist_track        17
# 11  index  sqlite_autoindex_playlist_track_1   playlist_track        18
# ...

# %%
pd.read_sql_query("SELECT * FROM invoice_items;", cnx)
# Out:
#       InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity
# 0                 1          1        2       0.99         1
# 1                 2          1        4       0.99         1
# 2                 3          2        6       0.99         1
# 3                 4          2        8       0.99         1
# 4                 5          2       10       0.99         1
# ...             ...        ...      ...        ...       ...
# 2235           2236        411     3136       0.99         1
# 2236           2237        411     3145       0.99         1
# 2237           2238        411     3154       0.99         1
# 2238           2239        411     3163       0.99         1
# 2239           2240        412     3177       1.99         1
#
# [2240 rows x 5 columns]

# %%
pd.read_sql_query('SELECT * FROM customers WHERE Fax is null and State is null;', cnx)
# Out:
#     CustomerId  FirstName    LastName Company  \
# 0            2     Leonie      Köhler    None
# 1            4      Bjørn      Hansen    None
# 2            6     Helena        Holý    None
# 3            7     Astrid      Gruber    None
# 4            8       Daan     Peeters    None
# 5            9       Kara     Nielsen    None
# 6           34       João   Fernandes    None
# 7           35   Madalena     Sampaio    None
# 8           36     Hannah   Schneider    None
# 9           37       Fynn  Zimmermann    None
# 10          38     Niklas    Schröder    None
# 11          39    Camille     Bernard    None
# 12          40  Dominique    Lefebvre    None
# 13          41       Marc      Dubois    None
# 14          42      Wyatt      Girard    None
# 15          43   Isabelle     Mercier    None
# 16          44      Terhi  Hämäläinen    None
# 17          45   Ladislav      Kovács    None
# 18          49  Stanisław      Wójcik    None
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 clear_output
#
# NameError: name 'clear_output' is not defined
